# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
r = requests.get("https://th.theasianparent.com/200-first-name-in-english-meaning")

# %%
r.encoding = 'utf-8'

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
t = soup.find_all("table")

# %%
for j in t:
    td = j.find_all("td")
    n = 0
    for i in td:
        n = n + 1
        if n%3 == 0:
            print(i.text)
# Out:
# คำอ่าน
# อาร์มันโด้
# บาร์ธาซ่าร์
# บาร์นาบี้
# บาสเตียน
# คอสโม่
# ครูส
# ดีอ้อน
# แกสทอน
# กันนาร์
# ลูเซียโน่
# มิเกล
# นิคาซิโอ้
# นิโค
# โอดิน
# โอลิเวอร์
# เปาโล
# ปาสคาล
# สเวน
# ทาดิโอ้
# มาทิลด้า
# ซีโน่
# เอซ
# อาแจ็กซ์
# แอนเจลโล่
# แอนโทนี่
# อพอลโล่
# แอรีส
# อาร์จีนโต้
# อาร์เชอ
# ออสติน
# เซน
# เด็กซ์ตอน
# ไรเดอร์
# ไรเกอร์
# แคสเซียส
# ร็อกโก้
# ริชแมน
# อีเมอร์สัน
# แร็กกี้
# ไบรอันต์
# เทรย์เวอร์
# โคลด์
# วอล์กเกอร์
# อับบาส
# แอนดริว
# โบการ์ด
# คริสโตเฟอร์
# โดโนแวน
# ดุ๊ก
# อีซีโอ
# คำอ่าน
# อีคอน
# กูเรี่ยน
# ฮาเกน
# ไฮด้า
# แลนเดอร์
# ลีโอ
# ลีโอนาร์ท
# โลเวล
# แม็กซ์
# นีอ้อน
# แร็คน่าร์
# เลนนี่
# ริชาร์ท
# ริกเกอร์
# โรเจอร์
# อูซี่
# วอลเลอร์
# วัลดัส
# เดม่อน
# แม็กซิมัส
# ฟีนิกซ์
# ซานเดอร์
# เมสัน
# บารอน
# อีธาน
# กัส
# เจคอป
# เบลซ
# แกนนอน
# เบนซ์
# ก๊อตดาร์ท
# เฮอร์คิวลิส
# เจ๊ด
# แมดด็อกซ์
# วัลโด้
# สเตนาร์ท
# อโมรี่
# อลัน
# อลาโน่
# โลคาซันเดอร์
# โดมินิก
# เอ็ดการ์ด
# ออสก้า
# เรนเดล
# แกริค
# แบรนเดอร์
# คาร์ดอส
# ไดนาดิน
# โอเว่น
# มอร์แกน
# ...

# %%
name = '''อาร์มันโด้
บาร์ธาซ่าร์
บาร์นาบี้
บาสเตียน
คอสโม่
ครูส
ดีอ้อน
แกสทอน
กันนาร์
ลูเซียโน่
มิเกล
นิคาซิโอ้
นิโค
โอดิน
โอลิเวอร์
เปาโล
ปาสคาล
สเวน
ทาดิโอ้
มาทิลด้า
ซีโน่
เอซ
อาแจ็กซ์
แอนเจลโล่
แอนโทนี่
อพอลโล่
แอรีส
อาร์จีนโต้
อาร์เชอ
ออสติน
เซน
เด็กซ์ตอน
ไรเดอร์
ไรเกอร์
แคสเซียส
ร็อกโก้
ริชแมน
อีเมอร์สัน
แร็กกี้
ไบรอันต์
เทรย์เวอร์
โคลด์
วอล์กเกอร์
อับบาส
แอนดริว
โบการ์ด
คริสโตเฟอร์
โดโนแวน
ดุ๊ก
อีซีโอ
คำอ่าน
อีคอน
กูเรี่ยน
ฮาเกน
ไฮด้า
แลนเดอร์
ลีโอ
ลีโอนาร์ท
โลเวล
แม็กซ์
นีอ้อน
แร็คน่าร์
เลนนี่
ริชาร์ท
ริกเกอร์
โรเจอร์
อูซี่
ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย P
Pierce เพียซ
Porter พอร์เตอร์
Peyton เพย์ตัน
Philip ฟิลิปป์
Paxton แพกซ์ตัน
Putter พัตเตอร์
Paul พอล
Parish พาริช
Prince พรินซ์
Pace เพซ
Perce เพิร์ซ
 

ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย Q
Quinton ควินตัน
Quinn ควินน์
Quint ควินต์
Quintan ควินตัน
Que คิว
 


ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย R
Rome โรม
Remi เรมี่
Ray เรย์
Rayden เรย์เดน
Roy รอย
Ronin โรนิน
Remy เรมี่
Raiden ไรเดน
Raymond เรย์มอน
Riley ไรลี่ย์
Rowan โรแวน
Roman โรมัน
Rex เร็กซ์
Rock ร็อค
Rocco ร็อคโค่
Ryder ไรเดอร์
River รีเวอร์
Ren เรน
Ryan ไรอัน

ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย S
Saint เซนต์
Shane เชน
Seth เซทท์
Sean ฌอน
Shane เชน
Shawn ชอว์น
Sander แซนเดอร์
 

ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย T
Titan ไททัน
Trey เทรย์
Troy ทรอย
Tyson ไทสัน
Travis ทราวิส
Theo ธีโอ
Tyler ไทเลอร์
Tevin เทวิน
Tan แทน
 

ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย U
Usher อัชเชอร์
 

ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย V
Vin วิน
Vince วินซ์
Van แวน
Victor  วิกเตอร์
ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย W
Westin เวสติน
Wells เวลส์
Walter วอลเตอร์
Weston เวสตัน
Willie วิลลี่
Wish วิช
White ไวท์   
ชื่อลูกชายแบบอินเตอร์ๆ ขึ้นต้นด้วย Z
Zayne เซย์น
Zion ไซออน
Zander แซนเดอร์
Zay เซย์
Zac แซค
Zein ซีน
Zone โซน'''

# %%
for i in name2.split("\n"):
    arr_line = i.split(" ")
    if(len(arr_line) > 1):
        name_tmp = arr_line[1]
        if name_tmp == "ขึ้นต้นด้วย":
            continue;
        else:
            if name_tmp in arr_name:
                continue
            else:
                arr_name.append(name_tmp)

# %%
len(arr_name)
# Out:
# 446

# %%
f = open("name3.csv","w")
for i in arr_name:
    f.write(i+"\n")
    print(i)
f.close()
# Out:
# อาร์มันโด้
# บาร์ธาซ่าร์
# บาร์นาบี้
# บาสเตียน
# คอสโม่
# ครูส
# ดีอ้อน
# แกสทอน
# กันนาร์
# ลูเซียโน่
# มิเกล
# นิคาซิโอ้
# นิโค
# โอดิน
# โอลิเวอร์
# เปาโล
# ปาสคาล
# สเวน
# ทาดิโอ้
# มาทิลด้า
# ซีโน่
# เอซ
# อาแจ็กซ์
# แอนเจลโล่
# แอนโทนี่
# อพอลโล่
# แอรีส
# อาร์จีนโต้
# อาร์เชอ
# ออสติน
# เซน
# เด็กซ์ตอน
# ไรเดอร์
# ไรเกอร์
# แคสเซียส
# ร็อกโก้
# ริชแมน
# อีเมอร์สัน
# แร็กกี้
# ไบรอันต์
# เทรย์เวอร์
# โคลด์
# วอล์กเกอร์
# อับบาส
# แอนดริว
# โบการ์ด
# คริสโตเฟอร์
# โดโนแวน
# ดุ๊ก
# อีซีโอ
# คำอ่าน
# อีคอน
# กูเรี่ยน
# ฮาเกน
# ไฮด้า
# แลนเดอร์
# ลีโอ
# ลีโอนาร์ท
# โลเวล
# แม็กซ์
# นีอ้อน
# แร็คน่าร์
# เลนนี่
# ริชาร์ท
# ริกเกอร์
# โรเจอร์
# อูซี่
# วอลเลอร์
# วัลดัส
# เดม่อน
# แม็กซิมัส
# ฟีนิกซ์
# ซานเดอร์
# เมสัน
# บารอน
# อีธาน
# กัส
# เจคอป
# เบลซ
# แกนนอน
# เบนซ์
# ก๊อตดาร์ท
# เฮอร์คิวลิส
# เจ๊ด
# แมดด็อกซ์
# วัลโด้
# สเตนาร์ท
# อโมรี่
# อลัน
# อลาโน่
# โลคาซันเดอร์
# โดมินิก
# เอ็ดการ์ด
# ออสก้า
# เรนเดล
# แกริค
# แบรนเดอร์
# คาร์ดอส
# ไดนาดิน
# โอเว่น
# มอร์แกน
# คำอ่าน
# ...

# %% [markdown]
# # รายชื่อประธานาธิปดี

# %%
import pandas as pd

# %%
r = requests.get("https://th.wikipedia.org/wiki/%E0%B8%A3%E0%B8%B2%E0%B8%A2%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%98%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%98%E0%B8%B4%E0%B8%9A%E0%B8%94%E0%B8%B5%E0%B8%AA%E0%B8%AB%E0%B8%A3%E0%B8%B1%E0%B8%90")

# %%
dfs = pd.read_html(r.text)
df = dfs[0]
arr = df.drop_duplicates("ประธานาธิบดี")["ประธานาธิบดี"].apply(lambda x: x.split(" ")[0]).values
mylist = list(dict.fromkeys(arr)) #drop duplicate
russia_ucrane_name_president = ["บอริส","วลาดีมีร์","ดมีตรี","วลาดีมีร์","แลออนิด","วิกตอร์","ออแลกซันดร์","แปตรอ","วอลอดือมือร์"]
mylist = mylist + russia_ucrane_name_president
for i in mylist:
    print(i)
# Out:
# จอร์จ
# จอห์น
# ทอมัส
# เจมส์
# แอนดรูว์
# มาร์ติน
# วิลเลียม
# แซคารี
# มิลลาร์ด
# แฟรงกลิน
# อับราฮัม
# ยูลิสซีส
# รัทเทอร์ฟอร์ด
# เชสเตอร์
# โกรเวอร์
# เบนจามิน
# ทีโอดอร์
# วูดโรว์
# วาร์เรน
# แคลวิน
# เฮอร์เบิร์ต
# แฮร์รี
# ดไวต์
# ลินดอน
# ริชาร์ด
# เจอรัลด์
# จิมมี
# โรนัลด์
# บิล
# บารัก
# ดอนัลด์
# โจ
# บอริส
# วลาดีมีร์
# ดมีตรี
# วลาดีมีร์
# แลออนิด
# วิกตอร์
# ออแลกซันดร์
# แปตรอ
# วอลอดือมือร์

# %%
def extract_html_tables(html):
  tables=[]
  maxlen=0
  rex1=r'<table.*?/table>'
  rex2=r'<tr.*?/tr>'
  rex3=r'<(td|th).*?/(td|th)>'
  s = re.search(rex1,html,re.DOTALL)
  while s:
    t = s.group()  # the table
    s2 = re.search(rex2,t,re.DOTALL)
    table = []
    while s2:
      r = s2.group() # the row 
      s3 = re.search(rex3,r,re.DOTALL)
      row=[]
      while s3:
        d = s3.group() # the cell
        #row.append(strip_tags(d).strip() )
        row.append(d.strip() )

        r = re.sub(rex3,'',r,1,re.DOTALL)
        s3 = re.search(rex3,r,re.DOTALL)

      table.append( row )
      if maxlen<len(row):
        maxlen = len(row)

      t = re.sub(rex2,'',t,1,re.DOTALL)
      s2 = re.search(rex2,t,re.DOTALL)

    html = re.sub(rex1,'',html,1,re.DOTALL)
    tables.append(table)
    s = re.search(rex1,html,re.DOTALL)
  return tables, maxlen

# %%
mylist = ["a", "b", "a", "c", "c"]
# Out:
# ['a', 'b', 'c']

# %%
dict.fromkeys(mylist)
# Out:
# {'a': None, 'b': None, 'c': None}
